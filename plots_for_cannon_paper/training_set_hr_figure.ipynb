# %%
# load training set
import pandas as pd
# %pylab inline
training_labels = pd.read_csv('./data/label_dataframes/training_labels.csv')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize=(7,7))
rcParams['font.size']=15
scatter(training_labels.galah_teff, training_labels.galah_logg,
       c=training_labels.galah_feh, s=15)
colorbar(label='[Fe/H] (dex)')
xlabel(r'T$_{\rm eff}$ (K)')
ylabel('log g (dex)')
tight_layout()
xlim(8100,3800);ylim(4.8,3.95)
# savefig('./data/cannon_models/gaia_rvs_model_figures/training_teff_vs_logg.png', dpi=300)
# Out:
# (4.8, 3.95)
